# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.33.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-158824
# aml-quickstarts-158824
# southcentralus
# 9a7511b8-150f-4a58-8528-3e7d50216c31

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'azure-mlops'
project_folder = './pipeline-mlops'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: azure-mlops,
# Workspace: quick-starts-ws-158824)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "mlops-compute"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS12_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=6)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded......................................................................................................................
# AmlCompute wait for completion finished
#
# Wait timeout has been reached
# Current provisioning state of AmlCompute is "Succeeded" and current node count is "0"

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "bankmarketing_train"
description_text = "Bank Marketing DataSet for Udacity Course 2"

dataset = Dataset.get_by_name(ws, name='bankmarketing_train')

# if key in ws.datasets.keys(): 
#         found = True
#         dataset = ws.datasets[key] 

# if not found:
#         # Create AML Dataset and register it into Workspace
#         example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
#         dataset = Dataset.Tabular.from_delimited_files(example_data)        
#         #Register Dataset in Workspace
#         dataset = dataset.register(workspace=ws,
#                                    name=key,
#                                    description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 30,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'accuracy'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [cbbb0f9a][f46a61cd-9d7a-40df-aa3a-c4f943ce1886], (This step will run and generate new outputs)
# Submitted PipelineRun 26c91d11-2203-452b-89e7-ebecd7801abb
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/26c91d11-2203-452b-89e7-ebecd7801abb?wsid=/subscriptions/9a7511b8-150f-4a58-8528-3e7d50216c31/resourcegroups/aml-quickstarts-158824/workspaces/quick-starts-ws-158824&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 26c91d11-2203-452b-89e7-ebecd7801abb
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/26c91d11-2203-452b-89e7-ebecd7801abb?wsid=/subscriptions/9a7511b8-150f-4a58-8528-3e7d50216c31/resourcegroups/aml-quickstarts-158824/workspaces/quick-starts-ws-158824&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
# PipelineRun Status: Running
#
#
# StepRunId: 20ce22d5-ca03-4d3e-8cec-5cd089252ac0
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/20ce22d5-ca03-4d3e-8cec-5cd089252ac0?wsid=/subscriptions/9a7511b8-150f-4a58-8528-3e7d50216c31/resourcegroups/aml-quickstarts-158824/workspaces/quick-starts-ws-158824&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': '20ce22d5-ca03-4d3e-8cec-5cd089252ac0', 'target': 'mlops-compute', 'status': 'Completed', 'startTimeUtc': '2021-09-20T12:29:37.284703Z', 'endTimeUtc': '2021-09-20T12:53:00.748805Z', 'properties': {'ContentSnapshotId': 'fa498bb9-7672-4608-8d81-653ed5b86d89', 'StepType': 'AutoMLStep', 'azureml.moduleid': 'f46a61cd-9d7a-40df-aa3a-c4f943ce1886', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'cbbb0f9a', 'azureml.pipelinerunid': '26c91d11-2203-452b-89e7-ebecd7801abb', 'azureml.pipelineComponent': 'masterautomlcloud', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'accuracy', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'mlops-compute', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "9a7511b8-150f-4a58-8528-3e7d50216c31", "resource_group": "aml-quickstarts-158824", "workspace_name": "quick-starts-ws-158824", "region": "southcentralus", "compute_target": "mlops-compute", "spark_service": null, "azure_service": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "enable_batch_run": false, "enable_run_restructure": false, "start_auxiliary_runs_before_parent_complete": false, "enable_code_generation": false, "iterations": 1000, "primary_metric": "accuracy", "task_type": "classification", "data_script": null, "test_size": 0.0, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 30, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["KNN", "RandomForest", "MultinomialNaiveBayes", "SVM", "LinearSVM", "LogisticRegression", "BernoulliNaiveBayes", "DecisionTree", "LightGBM", "ExtremeRandomTrees", "TensorFlowDNN", "XGBoostClassifier", "GradientBoosting", "SGD", "TensorFlowLinearClassifier", "AveragedPerceptronClassifier"], "private_models": [], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS12_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "save_mlflow": false, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_metric_confidence": false, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "_local_managed_run_id": null, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"7ad2b168-d01a-44a0-bdbd-16de079332d7\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': 'fa498bb9-7672-4608-8d81-653ed5b86d89', 'SetupRunId': '20ce22d5-ca03-4d3e-8cec-5cd089252ac0_setup', 'SetupRunContainerId': 'dcid.20ce22d5-ca0 ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '26c91d11-2203-452b-89e7-ebecd7801abb', 'status': 'Completed', 'startTimeUtc': '2021-09-20T12:29:17.926841Z', 'endTimeUtc': '2021-09-20T12:54:28.392196Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg158824.blob.core.windows.net/azureml/ExperimentRun/dcid.26c91d11-2203-452b-89e7-ebecd7801abb/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=l5Z6oTcVnZ8W6sa6MYLrvWR6Ag9trE%2FjvPoYXb5y6vw%3D&st=2021-09-20T12%3A19%3A30Z&se=2021-09-20T20%3A29%3A30Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg158824.blob.core.windows.net/azureml/ExperimentRun/dcid.26c91d11-2203-452b-89e7-ebecd7801abb/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=JfFgz4x69u2xLqhOYroPQkMUYmD9EKgG70k2z%2FTfQCY%3D&st=2021-09-20T12%3A19%3A30Z&se=2021-09-20T20%3A29%3A30Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg158824.blob.core.windows.net/azureml/ExperimentRun/dcid.26c91d11-2203-452b-89e7-ebecd7801abb/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=nLng4H7KBl4z7r9xguP1rp9GVxHlHxy6U1w%2BUGs0MOk%3D&st=2021-09-20T12%3A19%3A30Z&se=2021-09-20T20%3A29%3A30Z&sp=r'}, 'submittedBy': 'ODL_User 158824'}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/20ce22d5-ca03-4d3e-8cec-5cd089252ac0/metrics_data
# Downloaded azureml/20ce22d5-ca03-4d3e-8cec-5cd089252ac0/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_6  \
# norm_macro_recall                                 [0.26780643404520177]
# recall_score_micro                                 [0.9050075872534142]
# matthews_correlation                               [0.4001078038266774]
# f1_score_binary                                   [0.40152963671128106]
# f1_score_weighted                                  [0.8871655303279884]
# AUC_macro                                          [0.9214624699220335]
# average_precision_score_weighted                   [0.9440104615326564]
# precision_score_weighted                            [0.889730375483731]
# f1_score_macro                                     [0.6749695323823424]
# AUC_weighted                                       [0.9214624699220336]
# recall_score_macro                                 [0.6339032170226009]
# precision_score_macro                              [0.7988842580533124]
# f1_score_micro                                     [0.9050075872534142]
# precision_score_micro                              [0.9050075872534142]
# recall_score_weighted                              [0.9050075872534142]
# AUC_binary                                         [0.9214624699220334]
# accuracy                                           [0.9050075872534142]
# weighted_accuracy                                  [0.9723154691325931]
# average_precision_score_micro                      [0.9741632043235319]
# AUC_micro                                          [0.9737384780821634]
# average_precision_score_macro                      [0.7895864147291611]
# recall_score_binary                                [0.2845528455284553]
# balanced_accuracy                                  [0.6339032170226009]
# log_loss                                           [0.3408271134784256]
# average_precision_score_binary                     [0.5905925804634132]
# precision_score_binary                             [0.6818181818181818]
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_1  \
# norm_macro_recall                                 [0.43834549418631563]
# recall_score_micro                                 [0.9071320182094081]
# matthews_correlation                                [0.488678780261868]
# f1_score_binary                                    [0.5349544072948328]
# f1_score_weighted                                  [0.9021127651963996]
# AUC_macro                                          [0.9392346349984347]
# average_precision_score_weighted                   [0.9505970434373063]
# precision_score_weighted                           [0.8991976076061607]
# f1_score_macro                                     [0.7416848907681176]
# AUC_weighted                                       [0.9392346349984347]
# recall_score_macro                                 [0.7191727470931578]
# precision_score_macro                              [0.7723958081530135]
# f1_score_micro                                     [0.9071320182094081]
# precision_score_micro                              [0.9071320182094081]
# recall_score_weighted                              [0.9071320182094081]
# AUC_binary                                         [0.9392346349984347]
# accuracy                                           [0.9071320182094081]
# weighted_accuracy                                  [0.9537972210153172]
# average_precision_score_micro                      [0.9791945367231853]
# AUC_micro                                          [0.9781770788959222]
# average_precision_score_macro                      [0.8065229883244922]
# recall_score_binary                               [0.47696476964769646]
# balanced_accuracy                                  [0.7191727470931578]
# log_loss                                          [0.18743634958563793]
# average_precision_score_binary                       [0.62086635492726]
# precision_score_binary                             [0.6089965397923875]
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_2  \
# norm_macro_recall                                  [0.4585660381552552]
# recall_score_micro                                  [0.721092564491654]
# matthews_correlation                               [0.3069264664635514]
# f1_score_binary                                    [0.3726962457337884]
# f1_score_weighted                                  [0.7705138569281356]
# AUC_macro                                          [0.8312322750705292]
# average_precision_score_weighted                   [0.9147704355049457]
# precision_score_weighted                           [0.8771396838883415]
# f1_score_macro                                     [0.5966895862815284]
# AUC_weighted                                       [0.8312322750705293]
# recall_score_macro                                 [0.7292830190776276]
# precision_score_macro                              [0.6027156919369455]
# f1_score_micro                                      [0.721092564491654]
# precision_score_micro                               [0.721092564491654]
# recall_score_weighted                               [0.721092564491654]
# AUC_binary                                         [0.8312322750705292]
# accuracy                                            [0.721092564491654]
# weighted_accuracy                                  [0.7190590961660047]
# average_precision_score_micro                      [0.8095304933057738]
# AUC_micro                                          [0.8311445354505493]
# average_precision_score_macro                      [0.7155504276474544]
# recall_score_binary                                [0.7398373983739838]
# balanced_accuracy                                  [0.7292830190776276]
# log_loss                                           [0.5592469076331468]
# average_precision_score_binary                     [0.4588316455237022]
# precision_score_binary                             [0.2490875912408759]
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_4  \
# norm_macro_recall                                 [0.36766343056458584]
# recall_score_micro                                 [0.9095599393019727]
# matthews_correlation                              [0.46546341997581103]
# f1_score_binary                                    [0.4931972789115647]
# f1_score_weighted                                  [0.8991543413248716]
# AUC_macro                                          [0.9429643954676048]
# average_precision_score_weighted                   [0.9525002838696751]
# precision_score_weighted                            [0.897492669340287]
# f1_score_macro                                     [0.7217735811418869]
# AUC_weighted                                       [0.9429643954676049]
# recall_score_macro                                 [0.6838317152822929]
# precision_score_macro                              [0.7946393050335192]
# f1_score_micro                                     [0.9095599393019727]
# precision_score_micro                              [0.9095599393019727]
# recall_score_weighted                              [0.9095599393019727]
# AUC_binary                                         [0.9429643954676047]
# accuracy                                           [0.9095599393019727]
# weighted_accuracy                                  [0.9656021514809137]
# average_precision_score_micro                      [0.9799167574185672]
# AUC_micro                                          [0.9789146658499912]
# average_precision_score_macro                      [0.8131455327750426]
# recall_score_binary                               [0.39295392953929537]
# balanced_accuracy                                  [0.6838317152822929]
# log_loss                                          [0.19050081379091163]
# average_precision_score_binary                     [0.6335702864485608]
# precision_score_binary                             [0.6621004566210046]
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_22  \
# norm_macro_recall                                   [0.4850513200962494]
# recall_score_micro                                   [0.908649468892261]
# matthews_correlation                                [0.5151250200131301]
# f1_score_binary                                     [0.5643994211287988]
# f1_score_weighted                                   [0.9059066731226589]
# AUC_macro                                           [0.9342054322798867]
# average_precision_score_weighted                    [0.9491261665803736]
# precision_score_weighted                             [0.903858418734615]
# f1_score_macro                                      [0.7566869117849453]
# AUC_weighted                                        [0.9342054322798868]
# recall_score_macro                                  [0.7425256600481247]
# precision_score_macro                               [0.7735316607229037]
# f1_score_micro                                       [0.908649468892261]
# precision_score_micro                                [0.908649468892261]
# recall_score_weighted                                [0.908649468892261]
# AUC_binary                                          [0.9342054322798867]
# accuracy                                             [0.908649468892261]
# weighted_accuracy                                   [0.9498935170552647]
# average_precision_score_micro                       [0.9773951424273158]
# AUC_micro                                           [0.9770392902291373]
# average_precision_score_macro                       [0.8051729711782807]
# recall_score_binary                                 [0.5284552845528455]
# balanced_accuracy                                   [0.7425256600481247]
# log_loss                                           [0.32027476978984715]
# average_precision_score_binary                      [0.6196720799581417]
# precision_score_binary                              [0.6055900621118012]
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_7  \
# norm_macro_recall                                  [0.3273307066631841]
# recall_score_micro                                 [0.9031866464339909]
# matthews_correlation                               [0.4207095778234261]
# f1_score_binary                                     [0.450946643717728]
# f1_score_weighted                                  [0.8913707568639371]
# AUC_macro                                          [0.9201125504078007]
# average_precision_score_weighted                   [0.9384630594105299]
# precision_score_weighted                           [0.8886598373043313]
# f1_score_macro                                      [0.698929803802615]
# AUC_weighted                                       [0.9201125504078008]
# recall_score_macro                                  [0.663665353331592]
# precision_score_macro                              [0.7703634967166262]
# f1_score_micro                                     [0.9031866464339909]
# precision_score_micro                              [0.9031866464339909]
# recall_score_weighted                              [0.9031866464339909]
# AUC_binary                                         [0.9201125504078007]
# accuracy                                           [0.9031866464339909]
# weighted_accuracy                                  [0.9626533045699655]
# average_precision_score_micro                       [0.967837725804172]
# AUC_micro                                          [0.9699423184527989]
# average_precision_score_macro                      [0.7627894020099621]
# recall_score_binary                               [0.35501355013550134]
# balanced_accuracy                                   [0.663665353331592]
# log_loss                                          [0.22559692519538332]
# average_precision_score_binary                     [0.5364129056725079]
# precision_score_binary                             [0.6179245283018868]
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_0  \
# norm_macro_recall                                  [0.5026785366965085]
# recall_score_micro                                 [0.9116843702579667]
# matthews_correlation                               [0.5323740218566827]
# f1_score_binary                                    [0.5800865800865801]
# f1_score_weighted                                  [0.9091539479147899]
# AUC_macro                                          [0.9450464668693166]
# average_precision_score_weighted                   [0.9531771295804466]
# precision_score_weighted                           [0.9072720074188747]
# f1_score_macro                                     [0.7653697272147331]
# AUC_weighted                                       [0.9450464668693167]
# recall_score_macro                                 [0.7513392683482543]
# precision_score_macro                              [0.7819118765348991]
# f1_score_micro                                     [0.9116843702579667]
# precision_score_micro                              [0.9116843702579667]
# recall_score_weighted                              [0.9116843702579667]
# AUC_binary                                         [0.9450464668693166]
# accuracy                                           [0.9116843702579667]
# weighted_accuracy                                  [0.9514937218005303]
# average_precision_score_micro                      [0.9806603102489483]
# AUC_micro                                           [0.979695082216353]
# average_precision_score_macro                      [0.8151093723721079]
# recall_score_binary                                [0.5447154471544715]
# balanced_accuracy                                  [0.7513392683482543]
# log_loss                                          [0.17775706110025447]
# average_precision_score_binary                     [0.6371925714329306]
# precision_score_binary                             [0.6203703703703703]
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_19  \
# norm_macro_recall                                   [0.7200141892054601]
# recall_score_micro                                  [0.8039453717754173]
# matthews_correlation                               [0.49894167637414044]
# f1_score_binary                                     [0.5157421289355323]
# f1_score_weighted                                   [0.8366259525845062]
# AUC_macro                                           [0.9129285705023831]
# average_precision_score_weighted                     [0.934371502926016]
# precision_score_weighted                            [0.9184051734712139]
# f1_score_macro                                      [0.6964174876032303]
# AUC_weighted                                        [0.9129285705023831]
# recall_score_macro                                  [0.8600070946027301]
# precision_score_macro                               [0.6728735351019591]
# f1_score_micro                                      [0.8039453717754173]
# precision_score_micro                               [0.8039453717754173]
# recall_score_weighted                               [0.8039453717754173]
# AUC_binary                                          [0.9129285705023831]
# accuracy                                            [0.8039453717754173]
# weighted_accuracy                                   [0.7900267624413388]
# average_precision_score_micro                       [0.8891381808558718]
# AUC_micro                                           [0.8842088877938478]
# average_precision_score_macro                       [0.7463431318571738]
# recall_score_binary                                 [0.9322493224932249]
# balanced_accuracy                                   [0.8600070946027301]
# log_loss                                            [0.4370758835629542]
# average_precision_score_binary                      [0.5040461108670155]
# precision_score_binary                             [0.35647668393782384]
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_18  \
# norm_macro_recall                                  [0.40523796557172687]
# recall_score_micro                                  [0.9113808801213961]
# matthews_correlation                                [0.4889506962886429]
# f1_score_binary                                      [0.522875816993464]
# f1_score_weighted                                     [0.90319224881425]
# AUC_macro                                           [0.9435974452020666]
# average_precision_score_weighted                    [0.9540484004282169]
# precision_score_weighted                            [0.9009382104187968]
# f1_score_macro                                      [0.7370150245890705]
# AUC_weighted                                        [0.9435974452020667]
# recall_score_macro                                  [0.7026189827858634]
# precision_score_macro                               [0.7949782642698036]
# f1_score_micro                                      [0.9113808801213961]
# precision_score_micro                               [0.9113808801213961]
# recall_score_weighted                               [0.9113808801213961]
# AUC_binary                                          [0.9435974452020666]
# accuracy                                            [0.9113808801213961]
# weighted_accuracy                                   [0.9632108123160349]
# average_precision_score_micro                       [0.9804688307126028]
# AUC_micro                                           [0.9795221066544474]
# average_precision_score_macro                       [0.8198923358945536]
# recall_score_binary                                [0.43360433604336046]
# balanced_accuracy                                   [0.7026189827858634]
# log_loss                                           [0.21153384732702168]
# average_precision_score_binary                      [0.6470162183198876]
# precision_score_binary                              [0.6584362139917695]
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_23  ...  \
# norm_macro_recall                                   [0.3445679979697951]  ...
# recall_score_micro                                  [0.9016691957511381]  ...
# matthews_correlation                               [0.42388176089166374]  ...
# f1_score_binary                                    [0.46179401993355473]  ...
# f1_score_weighted                                   [0.8916787107960293]  ...
# AUC_macro                                           [0.9222372264734267]  ...
# average_precision_score_weighted                    [0.9387796226115658]  ...
# precision_score_weighted                            [0.8881179340229034]  ...
# f1_score_macro                                      [0.7038429017503445]  ...
# AUC_weighted                                        [0.9222372264734269]  ...
# recall_score_macro                                  [0.6722839989848975]  ...
# precision_score_macro                               [0.7607261096144627]  ...
# f1_score_micro                                       [0.901669195751138]  ...
# precision_score_micro                               [0.9016691957511381]  ...
# recall_score_weighted                               [0.9016691957511381]  ...
# AUC_binary                                          [0.9222372264734267]  ...
# accuracy                                            [0.9016691957511381]  ...
# weighted_accuracy                                   [0.9586193353436112]  ...
# average_precision_score_micro                       [0.9676243742029321]  ...
# AUC_micro                                           [0.9698350146564091]  ...
# average_precision_score_macro                       [0.7627174253069757]  ...
# recall_score_binary                                [0.37669376693766937]  ...
# balanced_accuracy                                   [0.6722839989848975]  ...
# log_loss                                           [0.22572358581733762]  ...
# average_precision_score_binary                      [0.5358402488820151]  ...
# precision_score_binary                              [0.5965665236051502]  ...
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_57  \
# norm_macro_recall                                   [0.6813949137440793]
# recall_score_micro                                  [0.7696509863429438]
# matthews_correlation                                [0.4579910640181685]
# f1_score_binary                                     [0.4754664823773324]
# f1_score_weighted                                   [0.8102064623903129]
# AUC_macro                                           [0.9098406585569615]
# average_precision_score_weighted                    [0.9344491009593636]
# precision_score_weighted                            [0.9137348567907672]
# f1_score_macro                                      [0.6639436242335817]
# AUC_weighted                                        [0.9098406585569615]
# recall_score_macro                                  [0.8406974568720397]
# precision_score_macro                               [0.6539164810960674]
# f1_score_micro                                      [0.7696509863429438]
# precision_score_micro                               [0.7696509863429438]
# recall_score_weighted                               [0.7696509863429438]
# AUC_binary                                          [0.9098406585569615]
# accuracy                                            [0.7696509863429438]
# weighted_accuracy                                   [0.7520120694850797]
# average_precision_score_micro                       [0.8931383645946662]
# AUC_micro                                           [0.8826888581356311]
# average_precision_score_macro                       [0.7497328246843049]
# recall_score_binary                                 [0.9322493224932249]
# balanced_accuracy                                   [0.8406974568720397]
# log_loss                                            [0.4184859172188988]
# average_precision_score_binary                      [0.5117038335516032]
# precision_score_binary                             [0.31910946196660483]
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_56  \
# norm_macro_recall                                   [0.5038075602902303]
# recall_score_micro                                  [0.5635811836115326]
# matthews_correlation                                [0.3191778532639769]
# f1_score_binary                                     [0.3379373848987109]
# f1_score_weighted                                    [0.636820931767754]
# AUC_macro                                           [0.8549755764133171]
# average_precision_score_weighted                    [0.9119553917940468]
# precision_score_weighted                            [0.9096168634175994]
# f1_score_macro                                       [0.506225369678871]
# AUC_weighted                                        [0.8549755764133171]
# recall_score_macro                                  [0.7519037801451152]
# precision_score_macro                               [0.6011045784580064]
# f1_score_micro                                      [0.5635811836115326]
# precision_score_micro                               [0.5635811836115326]
# recall_score_weighted                               [0.5635811836115326]
# AUC_binary                                          [0.8549755764133171]
# accuracy                                            [0.5635811836115326]
# weighted_accuracy                                   [0.5168257769322864]
# average_precision_score_micro                       [0.8052346352739194]
# AUC_micro                                           [0.7676177405873156]
# average_precision_score_macro                       [0.6806297150971377]
# recall_score_binary                                  [0.994579945799458]
# balanced_accuracy                                   [0.7519037801451152]
# log_loss                                            [0.5143034865894955]
# average_precision_score_binary                     [0.38253894281856277]
# precision_score_binary                             [0.20354963948973934]
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_47  \
# norm_macro_recall                                  [0.35643339686985387]
# recall_score_micro                                   [0.903793626707132]
# matthews_correlation                               [0.43761191684250744]
# f1_score_binary                                    [0.47429519071310117]
# f1_score_weighted                                   [0.8941089283842334]
# AUC_macro                                            [0.927585037982984]
# average_precision_score_weighted                    [0.9445481588848416]
# precision_score_weighted                            [0.8908853811646744]
# f1_score_macro                                      [0.7106735682979236]
# AUC_weighted                                         [0.927585037982984]
# recall_score_macro                                  [0.6782166984349269]
# precision_score_macro                               [0.7686395150459182]
# f1_score_micro                                       [0.903793626707132]
# precision_score_micro                                [0.903793626707132]
# recall_score_weighted                                [0.903793626707132]
# AUC_binary                                           [0.927585037982984]
# accuracy                                             [0.903793626707132]
# weighted_accuracy                                   [0.9597982762444559]
# average_precision_score_micro                         [0.97610935035657]
# AUC_micro                                           [0.9749026091401649]
# average_precision_score_macro                       [0.7849488333470349]
# recall_score_binary                                 [0.3875338753387534]
# balanced_accuracy                                   [0.6782166984349269]
# log_loss                                           [0.20125780098644455]
# average_precision_score_binary                      [0.5792860341107918]
# precision_score_binary                              [0.6111111111111112]
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_58  \
# norm_macro_recall                                   [0.5612395734346953]
# recall_score_micro                                   [0.824886191198786]
# matthews_correlation                                [0.4237124935964701]
# f1_score_binary                                    [0.48064806480648065]
# f1_score_weighted                                   [0.8483212744519947]
# AUC_macro                                           [0.8724157029676927]
# average_precision_score_weighted                    [0.9161312821550776]
# precision_score_weighted                            [0.8928309122200481]
# f1_score_macro                                      [0.6876684383167282]
# AUC_weighted                                        [0.8724157029676926]
# recall_score_macro                                  [0.7806197867173477]
# precision_score_macro                               [0.6599426392289395]
# f1_score_micro                                       [0.824886191198786]
# precision_score_micro                                [0.824886191198786]
# recall_score_weighted                                [0.824886191198786]
# AUC_binary                                          [0.8724157029676927]
# accuracy                                             [0.824886191198786]
# weighted_accuracy                                   [0.8358763420455465]
# average_precision_score_micro                       [0.7692532977794796]
# AUC_micro                                           [0.8285085463098777]
# average_precision_score_macro                        [0.689606607705594]
# recall_score_binary                                 [0.7235772357723578]
# balanced_accuracy                                   [0.7806197867173477]
# log_loss                                             [0.508786975095662]
# average_precision_score_binary                      [0.3977025004271241]
# precision_score_binary                             [0.35983827493261455]
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_38  \
# norm_macro_recall                                                  [0.0]
# recall_score_micro                                  [0.8880121396054628]
# matthews_correlation                                               [0.0]
# f1_score_binary                                                    [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# AUC_macro                                           [0.9111410269946856]
# average_precision_score_weighted                     [0.936338602897839]
# precision_score_weighted                             [0.788565560086672]
# f1_score_macro                                      [0.4703423886834914]
# AUC_weighted                                        [0.9111410269946856]
# recall_score_macro                                                 [0.5]
# precision_score_macro                               [0.4440060698027314]
# f1_score_micro                                      [0.8880121396054628]
# precision_score_micro                               [0.8880121396054628]
# recall_score_weighted                               [0.8880121396054628]
# AUC_binary                                          [0.9111410269946855]
# accuracy                                            [0.8880121396054628]
# weighted_accuracy                                   [0.9843450583187134]
# average_precision_score_micro                       [0.9699301124161823]
# AUC_micro                                           [0.9697852772743913]
# average_precision_score_macro                       [0.7616063837932114]
# recall_score_binary                                                [0.0]
# balanced_accuracy                                                  [0.5]
# log_loss                                           [0.25657974632710634]
# average_precision_score_binary                       [0.536443043179309]
# precision_score_binary                                             [0.0]
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_50  \
# norm_macro_recall                                  [0.23159895303669376]
# recall_score_micro                                  [0.9044006069802731]
# matthews_correlation                               [0.38083823488429847]
# f1_score_binary                                    [0.36363636363636365]
# f1_score_weighted                                   [0.8828410153260369]
# AUC_macro                                           [0.9252894801675289]
# average_precision_score_weighted                    [0.9429855426139095]
# precision_score_weighted                             [0.889822532217011]
# f1_score_macro                                      [0.6559773286598554]
# AUC_weighted                                         [0.925289480167529]
# recall_score_macro                                  [0.6157994765183469]
# precision_score_macro                               [0.8131226614975432]
# f1_score_micro                                      [0.9044006069802731]
# precision_score_micro                               [0.9044006069802731]
# recall_score_weighted                               [0.9044006069802731]
# AUC_binary                                          [0.9252894801675289]
# accuracy                                            [0.9044006069802731]
# weighted_accuracy                                   [0.9760524611454814]
# average_precision_score_micro                       [0.9753058117160291]
# AUC_micro                                           [0.9741623511044692]
# average_precision_score_macro                       [0.7796896085168092]
# recall_score_binary                                [0.24390243902439024]
# balanced_accuracy                                   [0.6157994765183469]
# log_loss                                           [0.21486310423012864]
# average_precision_score_binary                      [0.5692632874961032]
# precision_score_binary                              [0.7142857142857143]
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_49  \
# norm_macro_recall                                                  [0.0]
# recall_score_micro                                  [0.8880121396054628]
# matthews_correlation                                               [0.0]
# f1_score_binary                                                    [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# AUC_macro                                           [0.8978460563826418]
# average_precision_score_weighted                    [0.9181181198007058]
# precision_score_weighted                             [0.788565560086672]
# f1_score_macro                                      [0.4703423886834914]
# AUC_weighted                                        [0.8978460563826418]
# recall_score_macro                                                 [0.5]
# precision_score_macro                               [0.4440060698027314]
# f1_score_micro                                      [0.8880121396054628]
# precision_score_micro                               [0.8880121396054628]
# recall_score_weighted                               [0.8880121396054628]
# AUC_binary                                          [0.8978460563826417]
# accuracy                                            [0.8880121396054628]
# weighted_accuracy                                   [0.9843450583187134]
# average_precision_score_micro                       [0.9647376405899726]
# AUC_micro                                           [0.9671409985700503]
# average_precision_score_macro                         [0.69007348145404]
# recall_score_binary                                                [0.0]
# balanced_accuracy                                                  [0.5]
# log_loss                                            [0.2223957288496935]
# average_precision_score_binary                      [0.3962107190949225]
# precision_score_binary                                             [0.0]
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_59  \
# norm_macro_recall                                   [0.6433387607970407]
# recall_score_micro                                  [0.7253414264036419]
# matthews_correlation                               [0.41917317909763174]
# f1_score_binary                                     [0.4354335620711167]
# f1_score_weighted                                   [0.7756262274158003]
# AUC_macro                                           [0.9003879802981214]
# average_precision_score_weighted                    [0.9270025670250849]
# precision_score_weighted                            [0.9110672632413209]
# f1_score_macro                                       [0.626980867660784]
# AUC_weighted                                        [0.9003879802981215]
# recall_score_macro                                  [0.8216693803985203]
# precision_score_macro                               [0.6365580350367283]
# f1_score_micro                                      [0.7253414264036417]
# precision_score_micro                               [0.7253414264036419]
# recall_score_weighted                               [0.7253414264036419]
# AUC_binary                                          [0.9003879802981214]
# accuracy                                            [0.7253414264036419]
# weighted_accuracy                                   [0.7014258010537806]
# average_precision_score_micro                       [0.8559170374570009]
# AUC_micro                                           [0.8397540762778017]
# average_precision_score_macro                        [0.720046441365363]
# recall_score_binary                                   [0.94579945799458]
# balanced_accuracy                                   [0.8216693803985203]
# log_loss                                           [0.45423066579318677]
# average_precision_score_binary                      [0.4533587471734257]
# precision_score_binary                             [0.28282009724473256]
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_52  \
# norm_macro_recall                                   [0.1868955463307196]
# recall_score_micro                                  [0.9004552352048558]
# matthews_correlation                                [0.3355515932821952]
# f1_score_binary                                     [0.3080168776371308]
# f1_score_weighted                                   [0.8748823564609253]
# AUC_macro                                           [0.9001916283687785]
# average_precision_score_weighted                    [0.9311999125279159]
# precision_score_weighted                            [0.8834717477593308]
# f1_score_macro                                      [0.6271935271115674]
# AUC_weighted                                        [0.9001916283687785]
# recall_score_macro                                  [0.5934477731653598]
# precision_score_macro                               [0.8012240632930288]
# f1_score_micro                                      [0.9004552352048558]
# precision_score_micro                               [0.9004552352048558]
# recall_score_weighted                               [0.9004552352048558]
# AUC_binary                                          [0.9001916283687785]
# accuracy                                            [0.9004552352048558]
# weighted_accuracy                                   [0.9766768836179299]
# average_precision_score_micro                       [0.9694764994581062]
# AUC_micro                                           [0.9679878235520321]
# average_precision_score_macro                       [0.7389470570097479]
# recall_score_binary                                 [0.1978319783197832]
# balanced_accuracy                                   [0.5934477731653598]
# log_loss                                           [0.24742780930692418]
# average_precision_score_binary                      [0.4912062830823474]
# precision_score_binary                              [0.6952380952380952]
#
#                                  20ce22d5-ca03-4d3e-8cec-5cd089252ac0_55
# norm_macro_recall                                   [0.4123186754765702]
# recall_score_micro                                  [0.9092564491654022]
# matthews_correlation                                [0.4840063964126206]
# f1_score_binary                                     [0.5231259968102073]
# f1_score_weighted                                   [0.9020687114140309]
# AUC_macro                                           [0.9317464022213702]
# average_precision_score_weighted                    [0.9492765361455135]
# precision_score_weighted                            [0.8992566709887555]
# f1_score_macro                                      [0.7364917255558667]
# AUC_weighted                                          [0.93174640222137]
# recall_score_macro                                  [0.7061593377382851]
# precision_score_macro                               [0.7840790457739559]
# f1_score_micro                                       [0.909256449165402]
# precision_score_micro                               [0.9092564491654022]
# recall_score_weighted                               [0.9092564491654022]
# AUC_binary                                          [0.9317464022213702]
# accuracy                                            [0.9092564491654022]
# weighted_accuracy                                   [0.9596799682488474]
# average_precision_score_micro                       [0.9775605770563782]
# AUC_micro                                           [0.9764901526891576]
# average_precision_score_macro                       [0.8044318708498266]
# recall_score_binary                                 [0.4444444444444444]
# balanced_accuracy                                   [0.7061593377382851]
# log_loss                                           [0.21795111031023992]
# average_precision_score_binary                      [0.6177822141625802]
# precision_score_binary                              [0.6356589147286822]
#
# [26 rows x 62 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/20ce22d5-ca03-4d3e-8cec-5cd089252ac0/model_data
# Downloaded azureml/20ce22d5-ca03-4d3e-8cec-5cd089252ac0/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=False, enable_feature_sweeping=True, feature_sweeping_config={}, feature_sweeping_timeout=86400, featurization_config=None, force_text_dnn=False, is_cross_validation=False, is_onnx_compatible=False, observer=None, task='classification', working_dir='/m...
# ), random_state=0, reg_alpha=0, reg_lambda=1.0416666666666667, subsample=0.5, tree_method='hist'))], verbose=False))], flatten_transform=None, weights=[0.2, 0.13333333333333333, 0.06666666666666667, 0.2, 0.06666666666666667, 0.06666666666666667, 0.06666666666666667, 0.06666666666666667, 0.06666666666666667, 0.06666666666666667]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(
#       task='classification',
#       is_onnx_compatible=False,
#       enable_feature_sweeping=True,
#       enable_dnn=False,
#       force_text_dnn=False,
#       feature_sweeping_timeout=86400,
#       featurization_config=None,
#       is_cross_validation=False,
#       feature_sweeping_config={}
#   )),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(
#       estimators=[('43', Pipeline(
#           memory=None,
#           steps=[('standardscalerwrapper', StandardScalerWrapper(
#               copy=True,
#               with_mean=False,
#               with_std=False
#           )), ('xgboostclassifier', XGBoostClassifier(
#               random_state=0,
#               n_jobs=1,
#               problem_info=ProblemInfo(
#                   gpu_training_param_dict={'processing_unit_type': 'cpu'}
#               ),
#               booster='gbtree',
#               colsample_bytree=0.9,
#               eta=0.3,
#               gamma=0,
#               max_depth=6,
#               max_leaves=31,
#               n_estimators=400,
#               objective='reg:logistic',
#               reg_alpha=1.25,
#               reg_lambda=0.4166666666666667,
#               subsample=0.8,
#               tree_method='auto'
#           ))],
#           verbose=False
#       )), ('29', Pipeline(
#           memory=None,
#           steps=[('standardscalerwrapper', StandardScalerWrapper(
#               copy=True,
#               with_mean=False,
#               with_std=False
#           )), ('xgboostclassifier', XGBoostClassifier(
#               random_state=0,
#               n_jobs=1,
#               problem_info=ProblemInfo(
#                   gpu_training_param_dict={'processing_unit_type': 'cpu'}
#               ),
#               booster='gbtree',
#               colsample_bytree=1,
#               eta=0.05,
#               gamma=0,
#               max_depth=6,
#               max_leaves=0,
#               n_estimators=200,
#               objective='reg:logistic',
#               reg_alpha=0.625,
#               reg_lambda=0.8333333333333334,
#               subsample=0.8,
#               tree_method='auto'
#           ))],
#           verbose=False
#       )), ('34', Pipeline(
#           memory=None,
#           steps=[('sparsenormalizer', Normalizer(
#               copy=True,
#               norm='l1'
#           )), ('xgboostclassifier', XGBoostClassifier(
#               random_state=0,
#               n_jobs=1,
#               problem_info=ProblemInfo(
#                   gpu_training_param_dict={'processing_unit_type': 'cpu'}
#               ),
#               booster='gbtree',
#               colsample_bytree=1,
#               eta=0.5,
#               gamma=0,
#               grow_policy='lossguide',
#               max_bin=255,
#               max_depth=6,
#               max_leaves=0,
#               n_estimators=50,
#               objective='reg:logistic',
#               reg_alpha=2.291666666666667,
#               reg_lambda=2.3958333333333335,
#               subsample=0.5,
#               tree_method='hist'
#           ))],
#           verbose=False
#       )), ('31', Pipeline(
#           memory=None,
#           steps=[('standardscalerwrapper', StandardScalerWrapper(
#               copy=True,
#               with_mean=False,
#               with_std=False
#           )), ('xgboostclassifier', XGBoostClassifier(
#               random_state=0,
#               n_jobs=1,
#               problem_info=ProblemInfo(
#                   gpu_training_param_dict={'processing_unit_type': 'cpu'}
#               ),
#               booster='gbtree',
#               colsample_bylevel=0.6,
#               colsample_bytree=1,
#               eta=0.001,
#               gamma=0,
#               max_depth=6,
#               max_leaves=15,
#               n_estimators=800,
#               objective='reg:logistic',
#               reg_alpha=0,
#               reg_lambda=2.5,
#               subsample=1,
#               tree_method='auto'
#           ))],
#           verbose=False
#       )), ('0', Pipeline(
#           memory=None,
#           steps=[('maxabsscaler', MaxAbsScaler(
#               copy=True
#           )), ('lightgbmclassifier', LightGBMClassifier(
#               min_data_in_leaf=20,
#               random_state=None,
#               n_jobs=1,
#               problem_info=ProblemInfo()
#           ))],
#           verbose=False
#       )), ('41', Pipeline(
#           memory=None,
#           steps=[('standardscalerwrapper', StandardScalerWrapper(
#               copy=True,
#               with_mean=False,
#               with_std=False
#           )), ('xgboostclassifier', XGBoostClassifier(
#               random_state=0,
#               n_jobs=1,
#               problem_info=ProblemInfo(
#                   gpu_training_param_dict={'processing_unit_type': 'cpu'}
#               ),
#               booster='gbtree',
#               colsample_bytree=0.8,
#               eta=0.3,
#               gamma=0,
#               max_depth=6,
#               max_leaves=0,
#               n_estimators=400,
#               objective='reg:logistic',
#               reg_alpha=0.10416666666666667,
#               reg_lambda=0.625,
#               subsample=0.5,
#               tree_method='auto'
#           ))],
#           verbose=False
#       )), ('14', Pipeline(
#           memory=None,
#           steps=[('standardscalerwrapper', StandardScalerWrapper(
#               copy=True,
#               with_mean=False,
#               with_std=False
#           )), ('xgboostclassifier', XGBoostClassifier(
#               random_state=0,
#               n_jobs=1,
#               problem_info=ProblemInfo(
#                   gpu_training_param_dict={'processing_unit_type': 'cpu'}
#               ),
#               booster='gbtree',
#               colsample_bytree=1,
#               eta=0.3,
#               gamma=0,
#               max_depth=10,
#               max_leaves=511,
#               n_estimators=10,
#               objective='reg:logistic',
#               reg_alpha=2.1875,
#               reg_lambda=0.4166666666666667,
#               subsample=0.5,
#               tree_method='auto'
#           ))],
#           verbose=False
#       )), ('36', Pipeline(
#           memory=None,
#           steps=[('standardscalerwrapper', StandardScalerWrapper(
#               copy=True,
#               with_mean=False,
#               with_std=False
#           )), ('xgboostclassifier', XGBoostClassifier(
#               random_state=0,
#               n_jobs=1,
#               problem_info=ProblemInfo(
#                   gpu_training_param_dict={'processing_unit_type': 'cpu'}
#               ),
#               booster='gbtree',
#               colsample_bytree=1,
#               eta=0.05,
#               gamma=0,
#               max_depth=10,
#               max_leaves=127,
#               n_estimators=800,
#               objective='reg:logistic',
#               reg_alpha=1.3541666666666667,
#               reg_lambda=0.4166666666666667,
#               subsample=0.6,
#               tree_method='auto'
#           ))],
#           verbose=False
#       )), ('51', Pipeline(
#           memory=None,
#           steps=[('standardscalerwrapper', StandardScalerWrapper(
#               copy=True,
#               with_mean=False,
#               with_std=True
#           )), ('lightgbmclassifier', LightGBMClassifier(
#               boosting_type='gbdt',
#               colsample_bytree=0.99,
#               learning_rate=0.036848421052631586,
#               max_bin=10,
#               max_depth=10,
#               min_child_weight=0,
#               min_data_in_leaf=0.05172896551724139,
#               min_split_gain=0.9473684210526315,
#               n_estimators=100,
#               num_leaves=95,
#               reg_alpha=0.10526315789473684,
#               reg_lambda=0.2631578947368421,
#               subsample=0.8415789473684211,
#               random_state=None,
#               n_jobs=1,
#               problem_info=ProblemInfo()
#           ))],
#           verbose=False
#       )), ('33', Pipeline(
#           memory=None,
#           steps=[('standardscalerwrapper', StandardScalerWrapper(
#               copy=True,
#               with_mean=False,
#               with_std=False
#           )), ('xgboostclassifier', XGBoostClassifier(
#               random_state=0,
#               n_jobs=1,
#               problem_info=ProblemInfo(
#                   gpu_training_param_dict={'processing_unit_type': 'cpu'}
#               ),
#               booster='gbtree',
#               colsample_bytree=1,
#               eta=0.001,
#               gamma=0.1,
#               grow_policy='lossguide',
#               max_bin=7,
#               max_depth=8,
#               max_leaves=0,
#               n_estimators=600,
#               objective='reg:logistic',
#               reg_alpha=0,
#               reg_lambda=1.0416666666666667,
#               subsample=0.5,
#               tree_method='hist'
#           ))],
#           verbose=False
#       ))],
#       weights=[0.2, 0.13333333333333333, 0.06666666666666667, 0.2, 0.06666666666666667, 0.06666666666666667, 0.06666666666666667, 0.06666666666666667, 0.06666666666666667, 0.06666666666666667],
#       flatten_transform=None,
#       classification_labels=array([0, 1])
#   ))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_5788cc3e_1a12_11ec_86d4_39bfe99fecc4row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_5788cc3e_1a12_11ec_86d4_39bfe99fecc4row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_5788cc3e_1a12_11ec_86d4_39bfe99fecc4row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_5788cc3e_1a12_11ec_86d4_39bfe99fecc4row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_5788cc3e_1a12_11ec_86d4_39bfe99fecc4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5788cc3e_1a12_11ec_86d4_39bfe99fecc4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5788cc3e_1a12_11ec_86d4_39bfe99fecc4row0_col0" class="data row0 col0" >29049</td>
#                         <td id="T_5788cc3e_1a12_11ec_86d4_39bfe99fecc4row0_col1" class="data row0 col1" >209</td>
#             </tr>
#             <tr>
#                         <th id="T_5788cc3e_1a12_11ec_86d4_39bfe99fecc4level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5788cc3e_1a12_11ec_86d4_39bfe99fecc4row1_col0" class="data row1 col0" >756</td>
#                         <td id="T_5788cc3e_1a12_11ec_86d4_39bfe99fecc4row1_col1" class="data row1 col1" >2936</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 2473d21c-35da-4cae-b5a3-ba958ac2edca,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/9a7511b8-150f-4a58-8528-3e7d50216c31/resourceGroups/aml-quickstarts-158824/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-158824/PipelineRuns/PipelineSubmit/2473d21c-35da-4cae-b5a3-ba958ac2edca)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  545cb79b-3325-4fc6-b3f7-a54f1d565e59

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
